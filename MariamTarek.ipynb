# %%
import pandas as pd
#1 Reading a csv file
df =pd.read_csv('assignment.csv')

# %%
#2 Print the first 10 rows of your data
df.head(10)
# Out:
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
# ...

# %%
#3 Print the summary statistics of your data
df.describe()
# Out:
#               Apps       Accept      Enroll  Top10perc  Top25perc  \
# count     5.000000     5.000000    5.000000   5.000000   5.000000
# mean   1176.800000   949.600000  352.200000  27.400000  52.800000
# std     845.610253   717.186377  272.236478  18.514859  22.151749
# min     193.000000   146.000000   55.000000  16.000000  29.000000
# 25%     417.000000   349.000000  137.000000  16.000000  44.000000
# 50%    1428.000000  1097.000000  336.000000  22.000000  50.000000
# 75%    1660.000000  1232.000000  512.000000  23.000000  52.000000
# max    2186.000000  1924.000000  721.000000  60.000000  89.000000
#
#        F.Undergrad  P.Undergrad      Outstate  Room.Board       Books  \
# count     5.000000     5.000000      5.000000     5.00000    5.000000
# mean   1472.600000   559.000000  10298.000000  4614.00000  570.000000
# std    1232.310553   500.105989   2626.103578  1302.58589  189.076704
# min     249.000000    63.000000   7440.000000  3300.00000  400.000000
# ...

# %%
#4 Print the first 3 rows and the first 3 columns using iloc.
df.iloc[0:3,0:3]
# Out:
#                      Unnamed: 0 Private  Apps
# 0  Abilene Christian University     Yes  1660
# 1            Adelphi University     Yes  2186
# 2                Adrian College     Yes  1428

# %%
#5 Use value-counts to find out the unique values in a creatin column
df['Books'].value_counts().to_frame()
# Out:
#        count
# Books
# 450        2
# 750        1
# 400        1
# 800        1

# %%
#6 Rename one column into a new name
df.rename(columns={'Unnamed: 0':'ID'})
# Out:
#                              ID Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
# ...

# %%
#7 Drop one column from your data
df.drop(labels=['Top25perc'], axis=1)
# Out:
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  \
# 0         2885          537      7440        3300    450      2200   70
# 1         2683         1227     12280        6450    750      1500   29
# 2         1036           99     11250        3750    400      1165   53
# 3          510           63     12960        5450    450       875   92
# 4          249          869      7560        4120    800      1500   76
#
#    Terminal  S.F.Ratio  perc.alumni  Expend  Grad.Rate  PhD_enc
# ...

# %%
#8 Check the missing values and the duplicates then drop them
df.isna().sum()
# Out:
# Unnamed: 0     0
# Private        0
# Apps           0
# Accept         0
# Enroll         0
# Top10perc      0
# Top25perc      0
# F.Undergrad    0
# P.Undergrad    0
# Outstate       0
# Room.Board     0
# Books          0
# Personal       0
# PhD            0
# Terminal       0
# S.F.Ratio      0
# perc.alumni    0
# Expend         0
# Grad.Rate      0
# PhD_enc        0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 772    False
# 773    False
# 774    False
# 775    False
# 776    False
# Length: 777, dtype: bool

# %%
df.drop_duplicates()
# Out:
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
# ...

# %%
#9 Perform one hot encoding or label encoding on a certain column 
from sklearn.preprocessing import LabelEncoder
df['PhD_enc']=LabelEncoder().fit_transform(df['PhD'])
df[['PhD_enc', 'PhD']]
# Out:
#    PhD_enc  PhD
# 0        2   70
# 1        0   29
# 2        1   53
# 3        4   92
# 4        3   76

# %%
#10 Apply standardization or normalization on a certain column 
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df_scaled = scaler.fit_transform(df[['Enroll', 'Accept']])
print(pd.DataFrame(df_scaled))
# Out:
#           0         1
# 0  1.000000  0.610799
# 1  0.686186  1.000000
# 2  0.421922  0.534871
# 3  0.123123  0.114173
# 4  0.000000  0.000000

# %%
#11 Create any kind of graph to visualize your data
import matplotlib.pyplot as plt
df=df.head()
mylabels=['Student1','Student2','Student3','Student3','Student5']
df.plot(x='Enroll',y='F.Undergrad', kind='pie',labels=mylabels, layout=(100,100))
plt.legend=()
plt.show()
